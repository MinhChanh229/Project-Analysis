# %%
# import pandas, matplotlip, seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.Extract data:

# %%
# load data form csv
df = pd.read_csv('/content/Customer-Churn-Records.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 0        101348.88       1         1                   2   DIAMOND
# 1        112542.58       0         1                   3   DIAMOND
# 2        113931.57       1         1                   3   DIAMOND
# 3         93826.63       0         0                   5      GOLD
# 4         79084.10       0         0                   5      GOLD
#
#    Point Earned
# 0           464
# 1           456
# 2           377
# 3           350
# 4           425

# %%
# check random
df.sample(10)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 4304       4305    15770576     Hammond          555     Spain    Male   50
# 8562       8563    15647292        Peng          697    France    Male   63
# 8844       8845    15790717    Osinachi          695     Spain    Male   35
# 6032       6033    15579787  Nkemakonam          686    France    Male   39
# 9652       9653    15726720     Blinova          480    France  Female   40
# 5641       5642    15662232   Learmonth          675   Germany    Male   42
# 2202       2203    15751788     Johnson          850     Spain    Male   28
# 9665       9666    15745794       Cocci          547    France    Male   30
# 5194       5195    15791550       Kelly          696    France    Male   27
# 3173       3174    15727467      Mellor          485    France  Female   27
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4304       7  128061.00              2          1               1
# 8562       7  148368.02              1          0               0
# 8844       7       0.00              2          1               0
# 6032       4       0.00              2          1               0
# 9652       7       0.00              1          1               0
# 5641       2   92616.64              2          1               0
# 2202       9   97408.03              1          1               1
# 9665       6       0.00              2          1               1
# 5194       4   87637.26              2          0               0
# 3173       3       0.00              2          1               0
#
#       EstimatedSalary  Exited  Complain  Satisfaction Score Card Type  \
# 4304         62375.10       0         0                   4      GOLD
# 8562        118862.08       1         1                   5   DIAMOND
# 8844        160387.98       0         0                   5  PLATINUM
# 6032        155023.93       0         0                   4   DIAMOND
# 9652        170332.67       1         1                   1      GOLD
# 5641          8567.18       0         0                   1   DIAMOND
# 2202        175853.64       0         0                   3      GOLD
# 9665         18471.86       0         0                   5  PLATINUM
# 5194        196111.35       0         0                   5      GOLD
# 3173        141449.86       0         0                   5    SILVER
#
#       Point Earned
# 4304           977
# 8562           505
# 8844           950
# 6032           977
# 9652           751
# 5641           960
# 2202           962
# 9665           458
# 5194           685
# 3173           901

# %% [markdown]
# # 2. Transform data:

# %% [markdown]
# ### Data exploration
# ### Show the columns of the dataframe and their types:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  object
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
#  15  Satisfaction Score  10000 non-null  int64
#  16  Card Type           10000 non-null  object
#  17  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(12), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# #### Check missing value:

# %%
print(df.isnull().sum())
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Complain              0
# Satisfaction Score    0
# Card Type             0
# Point Earned          0
# dtype: int64

# %% [markdown]
# ### Fix data type

# %%
df['Surname'] = df['Surname'].astype('string')
df['Geography'] = df['Geography'].astype('string')
df['Gender'] = df['Gender'].astype('string')
df['Card Type'] = df['Card Type'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RowNumber           10000 non-null  int64
#  1   CustomerId          10000 non-null  int64
#  2   Surname             10000 non-null  string
#  3   CreditScore         10000 non-null  int64
#  4   Geography           10000 non-null  string
#  5   Gender              10000 non-null  string
#  6   Age                 10000 non-null  int64
#  7   Tenure              10000 non-null  int64
#  8   Balance             10000 non-null  float64
#  9   NumOfProducts       10000 non-null  int64
#  10  HasCrCard           10000 non-null  int64
#  11  IsActiveMember      10000 non-null  int64
#  12  EstimatedSalary     10000 non-null  float64
#  13  Exited              10000 non-null  int64
#  14  Complain            10000 non-null  int64
#  15  Satisfaction Score  10000 non-null  int64
#  16  Card Type           10000 non-null  string
#  17  Point Earned        10000 non-null  int64
# dtypes: float64(2), int64(12), string(4)
# memory usage: 1.4 MB

# %% [markdown]
# ## Basic descriptive statistics:
# ### Show a descriptive statistics of the numeric columns:

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited      Complain  Satisfaction Score  \
# count     10000.000000  10000.000000  10000.000000        10000.000000
# mean     100090.239881      0.203800      0.204400            3.013800
# std       57510.492818      0.402842      0.403283            1.405919
# min          11.580000      0.000000      0.000000            1.000000
# 25%       51002.110000      0.000000      0.000000            2.000000
# 50%      100193.915000      0.000000      0.000000            3.000000
# 75%      149388.247500      0.000000      0.000000            4.000000
# max      199992.480000      1.000000      1.000000            5.000000
#
#        Point Earned
# count  10000.000000
# mean     606.515100
# std      225.924839
# min      119.000000
# 25%      410.000000
# 50%      605.000000
# 75%      801.000000
# max     1000.000000

# %% [markdown]
# ### Customer obvious analysis:

# %%
# Boxplots to compare distributions by churn
for col in ['Age', 'Balance', 'EstimatedSalary', 'CreditScore']:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x='Exited', y=col, data=df)
    plt.title(f'{col} vs. Exited')
    plt.show()

# %%
sns.violinplot(x='Exited', y='Balance', data=df)
plt.title('Balance vs Churn')
plt.xlabel('Exited')
plt.ylabel('Balance')
plt.show()

# %% [markdown]
# # 3.Load data:

# %%
df.to_csv("bank_customer_churn_cleaned.csv", index=False)
print("✅ ETL pipeline hoàn tất!")
# Out:
# ✅ ETL pipeline hoàn tất!

# %% [markdown]
# ### Other (Pairplot (Optional for smaller datasets))

# %%
# sns.pairplot(df, hue='Exited', vars=['Age', 'Balance', 'CreditScore', 'EstimatedSalary']
sns.pairplot(df, hue='Exited', vars=['Age', 'Balance', 'CreditScore', 'EstimatedSalary'])
plt.show()
